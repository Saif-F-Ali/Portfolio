# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %%
base_web = "https://editorial.rottentomatoes.com/guide/140-essential-action-movies-to-watch-now/"

# %%
r = requests.get(base_web)

# %%
r.url
# Out:
# 'https://editorial.rottentomatoes.com/guide/140-essential-action-movies-to-watch-now/'

# %%
r.status_code
# Out:
# 200

# %%
r.ok
# Out:
# True

# %%
r.content[:111]
# Out:
# b'<!DOCTYPE html>\n<html lang="en-US" class="hitim">\n<head prefix="og: http://ogp.me/ns# flixstertomatoes: http://'

# %%
soup = BeautifulSoup(r.content, 'html.parser')

# %%
# displaying the body to navigate through
soup.find('body')
# Out:
# <body class="body">
# <div aria-labelledby="navMenu" class="modal fade" id="navMenu" role="dialog">
# <div class="modal-dialog">
# <div class="modal-content">
# <div class="modal-body">
# <button aria-label="Close" class="close" data-dismiss="modal" type="button">
# <span class="glyphicon glyphicon-remove"></span>
# </button>
# <div class="pull-left">
# <ul class="list-inline social">
# <li><a class="unstyled fontelloIcon icon-facebook-squared" href="https://www.facebook.com/rottentomatoes" id="header-facebook-social-link" target="_blank"></a></li>
# <li><a class="unstyled fontelloIcon icon-twitter" href="https://twitter.com/rottentomatoes" id="header-twitter-social-link" target="_blank"></a></li>
# </ul>
# </div>
# <div class="items">
# <div class="item">
# <a class="homeTab unstyled navLink fullLink" href="https://www.rottentomatoes.com/">
#                             Home
#                         </a>
# </div>
# <div class="item">
# ...

# %%
# displaying tags that encode movies countdown only
countdown = soup.find_all('div', class_="row countdown-item")

# %%
# making sure it encompasses all movies
len(countdown)
# Out:
# 140

# %%
# selecting one item to explore
countdown[0]
# Out:
# <div class="row countdown-item" id="row-index-140" style="padding-left: 10px;">
# <div class="countdown-index-resposive">#140</div>
# <div class="col-sm-6 col-full-xs">
# <a class="article_movie_poster" href="https://www.rottentomatoes.com/m/1018009-running_scared">
# <div><img alt="" class="article_poster" sborder="" src="https://resizing.flixster.com/9aGZh9Pn4LmdUkGZUGEhLaTyDuM=/fit-in/180x240/v2/https://resizing.flixster.com/-XZAfHZM39UwaGJIFWKAE8fS0ak=/v3/t/assets/p9354_p_v12_ad.jpg" style="border-color: #EEEEEE; border-style: solid; border-width: 1px;"/></div>
# </a>
# </div>
# <div class="col-sm-18 col-full-xs countdown-item-content">
# <div class="row countdown-item-title-bar">
# <div class="col-sm-20 col-full-xs" style="height: 100%;">
# <div class="article_movie_title" style="float: left;">
# <div>
# <h2>
# <a href="https://www.rottentomatoes.com/m/1018009-running_scared">Running Scared</a> <span class="subtle start-year">(1986)</span>
# <br/>
# ...

# %% [markdown]
# ## EXTRACTING IMPORTANT TAGS
#
# - `<div class="row countdown-item" id="row-index-140" style="padding-left: 10px;">`
# - `<div class="info director">`
# - `<a href="https://www.rottentomatoes.com/m/1018009-running_scared">Running Scared</a>`
# - `<span class="subtle start-year">(1986)</span>`
# - `<span class="tMeterScore" style="margin-right: 10px;">63%</span>`
# - `<div class="countdown-index">#140</div>`
# - `<div class="info critics-consensus">`

# %% [markdown]
# ## 1. movie name list

# %%
import re

# %%
# finding tags with movie names
names = soup.find_all("a", href=re.compile("https://www.rottentomatoes.com/m/"))

# %%
len(names)
# Out:
# 420

# %%
# selecting the target tag containning the text name
names = names[1::3]
names[:11]
# Out:
# [<a href="https://www.rottentomatoes.com/m/1018009-running_scared">Running Scared</a>,
#  <a href="https://www.rottentomatoes.com/m/equilibrium">Equilibrium</a>,
#  <a href="https://www.rottentomatoes.com/m/hero">Hero</a>,
#  <a href="https://www.rottentomatoes.com/m/1017666-road_house">Road House</a>,
#  <a href="https://www.rottentomatoes.com/m/unstoppable-2010">Unstoppable</a>,
#  <a href="https://www.rottentomatoes.com/m/1018699-shaft">Shaft</a>,
#  <a href="https://www.rottentomatoes.com/m/the_villainess">The Villainess</a>,
#  <a href="https://www.rottentomatoes.com/m/highlander">Highlander</a>,
#  <a href="https://www.rottentomatoes.com/m/die_hard_2_1990">Die Hard 2</a>,
#  <a href="https://www.rottentomatoes.com/m/national_treasure">National Treasure</a>,
#  <a href="https://www.rottentomatoes.com/m/protector">The Protector</a>]

# %%
# extracting the text
names_list = [i.text for i in names]
names_list[:11]
# Out:
# ['Running Scared',
#  'Equilibrium',
#  'Hero',
#  'Road House',
#  'Unstoppable',
#  'Shaft',
#  'The Villainess',
#  'Highlander',
#  'Die Hard 2',
#  'National Treasure',
#  'The Protector']

# %%
# checking the integrity
len(names_list)
# Out:
# 140

# %% [markdown]
# ## 2. movie year list

# %%
years = soup.find_all("span", class_="subtle start-year")
years[:4]
# Out:
# [<span class="subtle start-year">(1986)</span>,
#  <span class="subtle start-year">(2002)</span>,
#  <span class="subtle start-year">(2002)</span>,
#  <span class="subtle start-year">(1989)</span>]

# %%
len(years)
# Out:
# 140

# %%
years_list = [i.text.strip("()") for i in years]
years_list[:11]
# Out:
# ['1986',
#  '2002',
#  '2002',
#  '1989',
#  '2010',
#  '1971',
#  '2017',
#  '1986',
#  '1990',
#  '2004',
#  '2005']

# %% [markdown]
# ## 3. movie score list

# %%
scores = soup.find_all("span", class_="tMeterScore")
scores[:4]
# Out:
# [<span class="tMeterScore" style="margin-right: 10px;">63%</span>,
#  <span class="tMeterScore" style="margin-right: 10px;">40%</span>,
#  <span class="tMeterScore" style="margin-right: 10px;">94%</span>,
#  <span class="tMeterScore" style="margin-right: 10px;">44%</span>]

# %%
len(scores)
# Out:
# 140

# %%
score_list = [i.text for i in scores]
score_list[:11]
# Out:
# ['63%', '40%', '94%', '44%', '87%', '88%', '85%', '69%', '69%', '46%', '53%']

# %% [markdown]
# ## 4. directors list

# %%
directors = soup.find_all("div", class_="info director")
directors[:4]
# Out:
# [<div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/peter_hyams">Peter Hyams</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/kurt_wimmer">Kurt Wimmer</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/zhang_yimou">Yimou Zhang</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/rowdy_herrington">Rowdy Herrington</a></div>]

# %%
len(directors)
# Out:
# 140

# %%
directors_list = [i.text for i in directors]
directors_list[:5]
# Out:
# ['\nDirected By: Peter Hyams',
#  '\nDirected By: Kurt Wimmer',
#  '\nDirected By: Yimou Zhang',
#  '\nDirected By: Rowdy Herrington',
#  '\nDirected By: Tony Scott']

# %%
# removing unnecessary text
directors_list = [i.removeprefix("\nDirected By: ") for i in directors_list]
directors_list[:11]
# Out:
# ['Peter Hyams',
#  'Kurt Wimmer',
#  'Yimou Zhang',
#  'Rowdy Herrington',
#  'Tony Scott',
#  'Gordon Parks',
#  'Jeong Byeong-gil',
#  'Russell Mulcahy',
#  'Renny Harlin',
#  'Jon Turteltaub',
#  'Prachya Pinkaew']

# %% [markdown]
# ## 5. critics consensus list

# %%
consensus = soup.find_all("div", class_="info critics-consensus")
consensus[:5]
# Out:
# [<div class="info critics-consensus">
#  <span class="descriptor">Critics Consensus:</span> <em>Running Scared</em> struggles to strike a consistent balance between violent action and humor, but the chemistry between its well-matched leads keeps things entertaining.
#              </div>,
#  <div class="info critics-consensus">
#  <span class="descriptor">Critics Consensus:</span> Equilibrium is a reheated mishmash of other sci-fi movies.
#              </div>,
#  <div class="info critics-consensus">
#  <span class="descriptor">Critics Consensus:</span> With death-defying action sequences and epic historic sweep, <em>Hero</em> offers everything a martial arts fan could ask for.
#              </div>,
#  <div class="info critics-consensus">
#  <span class="descriptor">Critics Consensus:</span> Whether <em>Road House</em> is simply bad or so bad it's good depends largely on the audience's fondness for Swayze -- and tolerance for violently cheesy action.
#              </div>,
# ...

# %%
len(consensus)
# Out:
# 140

# %%
# extracting text
con_list = [i.text for i in consensus]
con_list[:5]
# Out:
# ['\nCritics Consensus: Running Scared struggles to strike a consistent balance between violent action and humor, but the chemistry between its well-matched leads keeps things entertaining.\n            ',
#  '\nCritics Consensus: Equilibrium is a reheated mishmash of other sci-fi movies.\n            ',
#  '\nCritics Consensus: With death-defying action sequences and epic historic sweep, Hero offers everything a martial arts fan could ask for.\n            ',
#  "\nCritics Consensus: Whether Road House is simply bad or so bad it's good depends largely on the audience's fondness for Swayze -- and tolerance for violently cheesy action.\n            ",
#  "\nCritics Consensus: As fast, loud, and relentless as the train at the center of the story, Unstoppable is perfect popcorn entertainment -- and director Tony Scott's best movie in years.\n            "]

# %%
# removing unnecessary text
con_list = [i.removeprefix("\nCritics Consensus: ") for i in con_list]
con_list[:5]
# Out:
# ['Running Scared struggles to strike a consistent balance between violent action and humor, but the chemistry between its well-matched leads keeps things entertaining.\n            ',
#  'Equilibrium is a reheated mishmash of other sci-fi movies.\n            ',
#  'With death-defying action sequences and epic historic sweep, Hero offers everything a martial arts fan could ask for.\n            ',
#  "Whether Road House is simply bad or so bad it's good depends largely on the audience's fondness for Swayze -- and tolerance for violently cheesy action.\n            ",
#  "As fast, loud, and relentless as the train at the center of the story, Unstoppable is perfect popcorn entertainment -- and director Tony Scott's best movie in years.\n            "]

# %%
# removing terminal spaces
con_list = [i.strip() for i in con_list]
con_list[:5]
# Out:
# ['Running Scared struggles to strike a consistent balance between violent action and humor, but the chemistry between its well-matched leads keeps things entertaining.',
#  'Equilibrium is a reheated mishmash of other sci-fi movies.',
#  'With death-defying action sequences and epic historic sweep, Hero offers everything a martial arts fan could ask for.',
#  "Whether Road House is simply bad or so bad it's good depends largely on the audience's fondness for Swayze -- and tolerance for violently cheesy action.",
#  "As fast, loud, and relentless as the train at the center of the story, Unstoppable is perfect popcorn entertainment -- and director Tony Scott's best movie in years."]

# %% [markdown]
# ## Creating the DataFrame

# %%
rottentom_ActionMovies = pd.DataFrame()

# %%
rottentom_ActionMovies["movie_name"] = names_list
rottentom_ActionMovies["movie_year"] = years_list
rottentom_ActionMovies["movie_director"] = directors_list
rottentom_ActionMovies["movie_score"] = score_list
rottentom_ActionMovies["critics_consensus"] = con_list

# %%
rottentom_ActionMovies.head(11)
# Out:
#            movie_name movie_year    movie_director movie_score  \
# 0      Running Scared       1986       Peter Hyams         63%
# 1         Equilibrium       2002       Kurt Wimmer         40%
# 2                Hero       2002       Yimou Zhang         94%
# 3          Road House       1989  Rowdy Herrington         44%
# 4         Unstoppable       2010        Tony Scott         87%
# 5               Shaft       1971      Gordon Parks         88%
# 6      The Villainess       2017  Jeong Byeong-gil         85%
# 7          Highlander       1986   Russell Mulcahy         69%
# 8          Die Hard 2       1990      Renny Harlin         69%
# 9   National Treasure       2004    Jon Turteltaub         46%
# 10      The Protector       2005   Prachya Pinkaew         53%
#
#                                     critics_consensus
# 0   Running Scared struggles to strike a consisten...
# 1   Equilibrium is a reheated mishmash of other sc...
# ...

# %%
rottentom_ActionMovies.tail()
# Out:
#                      movie_name movie_year                   movie_director  \
# 135                 Hard-Boiled       1992                         John Woo
# 136                  The Matrix       1999  Lilly Wachowski, Lana Wachowski
# 137  Terminator 2: Judgment Day       1991                    James Cameron
# 138                    Die Hard       1988                   John McTiernan
# 139          Mad Max: Fury Road       2015                    George Miller
#
#     movie_score                                  critics_consensus
# 135         92%  Boasting impactful action as well as surprisin...
# 136         83%  Thanks to the Wachowskis' imaginative vision, ...
# 137         91%  T2 features thrilling action sequences and eye...
# 138         94%  Its many imitators (and sequels) have never co...
# 139         97%  With exhilarating action and a surprising amou...

# %%
# showing full text
pd.set_option('display.max_rows', None)     # No limit on rows displayed
pd.set_option('display.max_columns', None)  # No limit on columns displayed
pd.set_option('display.max_colwidth', None)  # No limit on column width

# %%
rottentom_ActionMovies.head()
# Out:
#        movie_name movie_year    movie_director movie_score  \
# 0  Running Scared       1986       Peter Hyams         63%
# 1     Equilibrium       2002       Kurt Wimmer         40%
# 2            Hero       2002       Yimou Zhang         94%
# 3      Road House       1989  Rowdy Herrington         44%
# 4     Unstoppable       2010        Tony Scott         87%
#
#                                                                                                                                                        critics_consensus
# 0  Running Scared struggles to strike a consistent balance between violent action and humor, but the chemistry between its well-matched leads keeps things entertaining.
# 1                                                                                                             Equilibrium is a reheated mishmash of other sci-fi movies.
# ...

# %%
rottentom_ActionMovies.isnull().sum()
# Out:
# movie_name           0
# movie_year           0
# movie_director       0
# movie_score          0
# critics_consensus    0
# dtype: int64
